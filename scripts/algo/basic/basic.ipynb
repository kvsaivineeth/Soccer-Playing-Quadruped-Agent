# %% [markdown]
# # Basic `dm_control` playground
# Just trying to mess around with the custom `dm_control` stack.
#
# ## Imports

# %%
from dm_control import suite
from dm_control import viewer
import numpy as np

# %% [markdown]
# ## Custom reward function

# %%
def custom_reward(physics):
  global timestep_c
  
  if timestep_c % 500 == 0:
    print('===========')
    print('timestep: {}'.format(timestep_c))
    print('ball in goal: {}'.format(physics.ball_in_goal()))
    print('ball_to_goal_distance: {}'.format(physics.ball_to_goal_distance()))
    print('===========')
    print()
    
  return 600

# %% [markdown]
# ## Observation to input

# %%
def to_input(obs):
  pass

# %% [markdown]
# ## Environment creation

# %%
task_kwargs = {
  'reward_func': custom_reward
}

env = suite.load(domain_name="quadruped", 
                 task_name="soccer", 
                 visualize_reward=True, 
                 task_kwargs=task_kwargs)

# %% [markdown]
# ## Step the simulator

# %%
timestep_c = 0
timestep = env.reset()

while not timestep.last():
  timestep = env.step(np.random.random(12,))
  timestep_c += 1
  
  if timestep_c % 100 == 0:
    print(timestep)
# Out:
# ===========
# timestep: 0
# ball in goal: False
# ball_to_goal_distance: 5.2
# ===========
#
# ===========
# timestep: 0
# ball in goal: False
# ball_to_goal_distance: 13.098024700118541
# ===========
#
# ===========
# timestep: 0
# ball in goal: False
# ball_to_goal_distance: 13.098024700118541
# ===========
#
# TimeStep(step_type=<StepType.MID: 1>, reward=600, discount=1.0, observation=OrderedDict([('egocentric_state', array([ 0.54591001,  0.73848074, -0.52617598, -0.2158797 ,  0.49451676,
#         0.62882767, -0.57109349, -0.05722534,  0.46246585,  0.64423577,
#        -0.65642929,  0.0103646 ,  0.47565368,  0.78692713, -0.71671655,
#        -0.07655526,  1.09035547, -0.43993439,  0.45022559, -0.95131148,
#         0.71818615,  0.06598793, -0.19448811,  0.89347842,  0.48258676,
#        -1.00976425,  1.3064641 ,  0.03819526,  0.26437998, -0.86558742,
#        -0.0987395 ,  0.87677898,  0.58441044,  0.50709108,  0.3897462 ,
#         0.44839635,  0.43393447,  0.42790706,  0.49071386,  0.4320021 ,
#         0.38467684,  0.44478476,  0.37517746,  0.53714144])), ('torso_velocity', array([-0.06928031, -0.11567657, -0.16342355])), ('torso_upright', array(0.99818065)), ('imu', array([ 0.51830329, -4.82492439,  4.92510457, -0.08698101, -0.23414073,
#        -0.48845591])), ('force_torque', array([ 5.30508854, -4.65668124, -6.1579473 , -5.24872471, -5.9548716 ,
#        -5.77998565, -5.7045934 ,  5.34663697, -6.14659188, -5.05674799,
#        -2.65629061,  3.89760286, -2.07439982, -2.78656134,  0.53600274,
#        -3.38922552,  2.62177676, -0.5353278 ,  2.79800616,  3.15934425,
#         0.48586399,  0.15096446,  0.92481196, -0.31157301])), ('ball_state', array([-12.26264301,   0.19188393,   5.55214908,   0.20662989,
#         -3.42254534,  -2.39430313, -16.89213686, -16.76539689,
#         -3.97896757])), ('goal_position', array([ 5.41273908,  3.58534133, -0.92708129])), ('goal_walls_positions', (array([3.29500071, 2.30458707, 0.13350946]), array([7.5136611 , 4.98550565, 0.00868927]), array([5.39424109, 3.7166924 , 1.26891615]), array([4.76029248, 4.65543092, 0.00523931])))]))
# TimeStep(step_type=<StepType.MID: 1>, reward=600, discount=1.0, observation=OrderedDict([('egocentric_state', array([ 0
#         0.07781924,  0.33983679, -0.04693675, -0.0526507 , -3.87281647,
#        -1.02784199, -0.07309174,  0.2825294 ,  0.14749342])), ('ball_state', array([ 1.90895649,  0.31705368, -0.59993542, -0.03778677, -0.40268702,
#         0.01353515,  1.34634271,  0.59411569, -2.12706554])), ('goal_position', array([ 4.79585015,  4.57135663, -0.98613202])), ('goal_walls_positions', (array([2.94425112, 2.93651795, 0.08572783]), array([ 6.58806665,  6.35704685, -0.06457332]), array([4.73052937, 4.73729333, 1.20662839]), array([ 3.94521261,  5.51734931, -0.07975813])))]))
# ===========
# timestep: 500
# ball in goal: False
# ball_to_goal_distance: 5.207974187570162
# ===========
#
# ===========
# timestep: 500
# ball in goal: False
# ball_to_goal_distance: 5.207974187570162
# ===========
#
# TimeStep(step_type=<StepType.MID: 1>, reward=600, discount=1.0, observation=OrderedDict([('egocentric_state', array([ 0.48217379,  0.66277173, -0.6927009 ,  0.03387245,  0.70201691,
#         0.77894006, -0.58533576, -0.19731591,  0.53615526,  0.86119517,
#        -0.72511157, -0.14448934,  0.39223285,  0.60341084, -0.55795601,
#        -0.04507092,  0.30088707, -0.58984309,  1.76877862, -0.59824018,
#         0.28852389,  0.63524951, -0.30843511, -0.46775   , -0.8276245 ,
#         0.13105701, -0.86035213,  0.3927584 , -0.89955283, -0.98211022,
#         0.45128826, -0.32824114,  0.4756562 ,  0.40516175,  0.43702277,
#         0.61471166,  0.62589284,  0.53184881,  0.56598176,  0.49490077,
#         0.6057802 ,  0.29305472,  0.29198209,  0.43331221])), ('torso_velocity', array([-0.1482628 , -0.14871209, -0.15282375])), ('torso_upright', array(0.99668605)), ('imu', array([ 1.07116585,  8.09200145, 14.83383086, -0.18358076, -0.5204646 ,
#         0.07405545])), ('force_torque', array([ 4.40813542, -2.79828755, -4.49739725,  6.38436377, -5.54282064,
#        -6.92843512,  5.92977144,  5.54098898, -7.4468254 ,  6.2101484 ,
#        -6.42436712, -6.37581644, -0.04379619, -0.69674161,  0.01790658,
#        -3.27507964, -3.92809292, -1.28927344,  3.32816982, -3.75167434,
#        -0.27711787, -4.00121738, -3.42720513, -0.05988176])), ('ball_state', array([ 1.84783807, -0.19127298, -0.67746751,  0.1522552 , -0.08952229,
#         0.14869336,  0.81438804,  0.47437388, -1.27781213])), ('goal_position', array([ 4.64538915,  4.74053526, -0.50943913])), ('goal_walls_positions', (array([2.87658085, 2.92258909, 0.39410329]), array([6.46167625, 6.40287471, 0.58039056]), array([4.69761582, 4.56936787, 1.68327018]), array([3.83314953, 5.51924203, 0.57401948])))]))
# TimeStep(step_type=<StepType.MID: 1>, reward=600, discount=1.0, observation=OrderedDict([('egocentric_state', array([ 0.50120979,  0.61215883, -0.55638536, -0.05010823,  0.54193972,
#         0.67171665, -0.58038234, -0.08738317,  0.50071181,  0.86933512,
#        -0.66283492, -0.21058092,  0.43059956,  0.82726415, -0.57786434,
#        -0.24746966,  0.75904423,  0.46782329,  0.50183521, -0.42589567,
#         0.01786482, -0.00991258,  0.59669118, -0.5452105 , -0.2103332 ,
#        -0.94519468, -1.30999286,  2.58144063,  1.54127491, -0.15597604,
#         0.61550423, -1.27998166,  0.48949989,  0.41644687,  0.37157645,
#         0.51824736,  0.69616582,  0.51104455,  0.49528139,  0.38795236,
#         0.57962189,  0.49737255,  0.61969053,  0.45910214])), ('torso_velocity', array([-0.0350801 , -0.00736072, -0.00228103])), ('torso_upright', array(0.9949895)), ('imu', array([-1.92024045,  2.02809108, 16.96891119,  0.40255333, -0.34685485,
#        -0.46189671])), ('force_torque', array([ 4.91774155, -5.78849971, -5.87908051,  7.01100275,  4.34555486,
#        -7.55737756, -4.18014917,  3.85784466,  4.03579399,  6.19287289,
#        -3.65860244, -6.8418264 , -3.22251643, -2.05544197, -0.48397307,
#        -1.58766443, -4.2904845 , -1.79576337,  0.19860815,  0.56548016,
#        -0.13747928,  0.79856821, -3.58263789,  1.27440475])), ('ball_state', array([ 1.94798825, -0.43933248, -0.50074261,  0.05141698, -0.13553141,
#         0.01552428,  0.51681369,  0.33702355, -0.72688029])), ('goal_position', array([ 4.14484073,  5.13051799, -0.16725228])), ('goal_walls_positions', (array([2.47660447, 3.15749304, 0.59048138]), array([5.64361598, 6.99739886, 1.06499305]), array([3.95843362, 5.0137595 , 2.02172461]), array([3.1371064 , 5.84336966, 0.78999064])))]))
# TimeStep(step_type=<StepType.MID: 1>, reward=600, discount=1.0, observation=OrderedDict([('egocentric_state', array([ 0.50810799,  0.75122387, -0.70908151, -0.04355455,  0.50439934,
#         0.65685189, -0.48994944, -0.1566622 ,  0.38512752,  0.83078851,
#        -0.8424651 ,  0.01638749,  0.41342212,  0.77496355, -0.60504625,
#        -0.16990741, -1.0041902 , -0.13906138, -0.19876042, -0.19076428,
#         2.0499188 ,  1.13481666, -0.79544316, -0.33193003, -0.24540027,
#         1.51469377,  0.34003387, -1.79863225, -0.90168966,  0.09119697,
#        -1.38259397,  0.72674119,  0.42568742,  0.42583581,  0.54651886,
#         0.59189627,  0.43635281,  0.41820768,  0.35291056,  0.60811106,
#         0.61583307,  0.45439782,  0.42791978,  0.5717604 ])), ('torso_velocity', array([0.10438861, 0.11669023, 0.03870081])), ('torso_upright', array(0.99968055)), ('imu', array([ 3.75994664,  3.58536548,  8.30952491, -1.12365744,  0.12729465,
#        -0.22834957])), ('force_torque', array([-2.26092019, -3.83373955, -1.87617761,  5.39537656,  4.05222695,
#        -4.2158728 ,  6.33788477,  0.53930503, -6.67717798,  6.30896678,
#         5.57725062, -6.32300698, -0.03216073,  0.07441044, -0.01344424,
#         0.10743242, -1.24198287,  0.02512898, -0.48029934, -3.73076522,
#        -0.46270913,  3.10200345, -3.81088314, -0.47112161])), ('ball_state', array([ 1.86386101, -0.79398917, -0.58693679, -0.09878416, -0.20218042,
#        -0.01774183,  0.28878578,  0.14659123, -0.47322887])), ('goal_position', array([ 4.36197818,  4.86977463, -0.81561345])), ('goal_walls_positions', (array([2.64896827, 3.05549378, 0.19630654]), array([6.04524162, 6.72492536, 0.17182766]), array([4.32925706, 4.9147315 , 1.38368376]), array([3.46660264, 5.70496741, 0.15431214])))]))
# TimeStep(step_type=<StepType.MID: 1>, reward=600, discount=1.0, observation=OrderedDict([('egocentric_state', array([ 0.53824078,  0.71265518, -0.52970764, -0.18070919,  0.60695433,
#         0.60760145, -0.42070362, -0.19025374,  0.52028103,  0.72067635,
#        -0.65209851, -0.0697159 ,  0.47190402,  0.77822287, -0.62968808,
#        -0.15185039, -1.0730502 ,  1.02353344, -1.47585491,  1.83363306,
#        -0.75022407,  0.90971505, -2.52882491,  2.20097718, -0.39363272,
#        -0.3867116 ,  0.49559776, -0.90480164, -0.77488578,  0.56156057,
#        -0.2906421 , -0.26189852,  0.48789052,  0.41308901,  0.5141366 ,
#         0.52146984,  0.48347302,  0.50785332,  0.46146978,  0.40679902,
#         0.52230411,  0.36169332,  0.53067899,  0.48884869])), ('torso_velocity', array([-0.07746476, -0.10348533,  0.08785971])), ('torso_upright', array(0.99943415)), ('imu', array([ 0.75172099,  5.58732486, 10.74900175,  0.29490579,  0.0319965 ,
#         0.41921126])), ('force_torque', array([ 2.37578515, -3.44329088, -3.287338  ,  4.69974647, -5.31521853,
#        -6.50942847,  6.8402665 , -5.0510757 , -6.71231146, -5.1204844 ,
#        -5.79541268, -5.38051563, -0.05288834, -0.25695437, -0.10413312,
#        -2.60939954, -2.45902575, -0.11561727, -2.60059179, -4.26952419,
#        -1.05027278, -3.24721226,  2.47651678,  0.36238473])), ('ball_state', array([ 1.94231816, -0.79313039, -0.56315898,  0.08594694,  0.05142145,
#        -0.11621323,  0.16791197,  0.09981447, -0.28494066])), ('goal_position', array([ 3.93382982,  5.1925429 , -0.83802285])), ('goal_walls_positions', (array([2.37694306, 3.24859879, 0.18529767]), array([5.45159681, 7.19121494, 0.13752493]), array([3.89079807, 5.25274361, 1.36073229]), array([2.96826374, 5.95718195, 0.12271087])))]))
# TimeStep(step_type=<StepType.LAST: 2>, reward=600, discount=1.0, observation=OrderedDict([('egocentric_state', array([ 0.5319542 ,  0.75152105, -0.68705339, -0.06202069,  0.44476117,
#         0.81121009, -0.7212748 , -0.08991565,  0.58036259,  0.70028168,
#        -0.61476229, -0.09069769,  0.42534632,  0.5407052 , -0.47337072,
#        -0.07106556,  1.51878427,  0.53181987,  0.50931245, -1.3323293 ,
#        -0.53447069, -0.48386848,  0.33409738, -0.47808919,  0.45655653,
#        -1.45952411,  0.52469522, -0.50683589,  1.68478346, -0.88698918,
#         0.77711785, -0.44419085,  0.62606713,  0.58033592,  0.51123035,
#         0.50959537,  0.48295986,  0.49471271,  0.44277704,  0.6247102 ,
#         0.46125129,  0.45276251,  0.54243349,  0.33813946])), ('torso_velocity', array([-0.08692195, -0.23092001, -0.22841347])), ('torso_upright', array(0.99756723)), ('imu', array([ 6.95685035, 11.79168147, 19.06606036,  0.58898584, -0.47922127,
#        -0.73756724])), ('force_torque', array([ 6.28916914,  5.72860345, -6.69837487, -3.63341319,  4.45722749,
#         1.28733367,  6.99888643, -6.90345422, -8.56466635,  0.31592784,
#        -3.15110873, -6.83116985,  2.99723887, -3.68646755, -0.93928714,
#         0.08838159,  0.00996559,  0.16503825, -4.0667545 , -3.99880672,
#         1.67464112, -1.16402704,  1.95145132,  0.23737029])), ('ball_state', array([ 1.93203828, -0.80589295, -0.75512821,  0.09090871,  0.20058685,
#         0.20712061,  0.08485022,  0.07015806, -0.17626033])), ('goal_position', array([ 3.77331127,  5.30762435, -0.91001141])), ('goal_walls_positions', (array([2.34551631, 3.28524973, 0.14895151]), array([5.33502514, 7.29121518, 0.02616014]), array([3.92062207, 5.26496219, 1.28463651]), array([2.88174943, 6.0059424 , 0.16584611])))]))
