# %% [markdown]
# # Basic `dm_control` playground
# Just trying to mess around with the custom `dm_control` stack.
#
# ## Imports

# %%
from dm_control import suite
from dm_control import viewer
import numpy as np

# %% [markdown]
# ## Custom reward function

# %%
def custom_reward(physics):
  global timestep_c
  
  if timestep_c % 500 == 0:
    print('===========')
    print('timestep: {}'.format(timestep_c))
    print('ball in goal: {}'.format(physics.ball_in_goal()))
    print('ball_to_goal_distance: {}'.format(physics.ball_to_goal_distance()))
    print('===========')
    print()
    
  return 600

# %% [markdown]
# ## Observation to input

# %%
def to_input(obs):
  pass

# %% [markdown]
# ## Environment creation

# %%
task_kwargs = {
  'reward_func': custom_reward
}

env = suite.load(domain_name="quadruped", 
                 task_name="soccer", 
                 visualize_reward=True, 
                 task_kwargs=task_kwargs)
# Out:
# <function custom_reward at 0x7f5539d18e18>

# %% [markdown]
# ## Step the simulator

# %%
timestep_c = 0
timestep = env.reset()

while not timestep.last():
  timestep = env.step(np.random.random(12,))
  timestep_c += 1
  
  if timestep_c % 100 == 0:
    print(timestep)
# Out:
# ===========
# timestep: 0
# ball in goal: False
# ball_to_goal_distance: 5.2
# ===========
#
# ===========
# timestep: 0
# ball in goal: False
# ball_to_goal_distance: 13.329171390896091
# ===========
#
# ===========
# timestep: 0
# ball in goal: False
# ball_to_goal_distance: 13.329171390896091
# ===========
#
# TimeStep(step_type=<StepType.MID: 1>, reward=600, discount=1.0, observation=OrderedDict([('egocentric_state', array([ 0.45980173,  0.73528011, -0.55246783, -0.17824074,  0.54015405,
#         0.61179544, -0.49312538, -0.12328184,  0.47269753,  0.70225756,
#        -0.63339833, -0.06976925,  0.33233596,  0.79568715, -0.61766351,
#        -0.17781024, -0.75262177, -0.07105701,  1.62668276, -1.04463842,
#        -1.42288854, -0.11811595,  0.17598433, -0.04334965, -0.32765063,
#        -1.15429033,  0.47364481,  0.20577111,  0.94354177, -0.59093765,
#         0.64623638,  0.25568988,  0.3117904 ,  0.65869194,  0.38549523,
#         0.47393824,  0.50873227,  0.32021411,  0.48201449,  0.4223775 ,
#         0.43982427,  0.38244218,  0.44277286,  0.41115354])), ('torso_velocity', array([-0.18301319,  0.1851454 , -0.09535827])), ('torso_upright', array(0.99876625)), ('imu', array([-1.4329486 , -0.72918235, 10.03660898,  0.42197816, -0.35243388,
#         0.36530261])), ('force_torque', array([ 6.59822346, -6.41283994, -7.19305367, -6.20439305, -2.51943792,
#        -6.0200609 ,  3.69287989,  5.27517426, -6.242156  , -3.50382993,
#        -0.84297098,  2.39626712, -3.77820044, -4.11223531,  1.36000423,
#         0.52727572,  3.6390039 , -0.64832581,  2.68121654, -0.22931246,
#         0.01256973, -0.08183547,  0.06999318,  0.04190695])), ('ball_state', array([13.41009439,  3.15097924, -0.34567381,  6.15624133, -5.2360731 ,
#        -1.97017098, 25.74139798, 31.79391067, -0.93006527]))]))
# TimeStep(step_type=<StepType.MID: 1>, reward=600, discount=1.0, observation=OrderedDict([('egocentric_state', array([ 0.50281302,  0.70581194, -0.6081468 , -0.0987611 ,  0.49826341,
#         0.71659156, -0.55486911, -0.16649293,  0.43803998,  0.78128213,
#        -0.68606532, -0.08602358,  0.47085008,  0.77590316, -0.74572342,
#        -0.01971828,  0.25705734,  0.66561922, -0.78066378,  0.14810501,
#         0.61336851, -0.34930262, -0.00973499, -0.61922381,  1.93496789,
#        -0.19373703,  0.04970429,  0.44404992,  0.53680828,  0.53035943,
#         0.93159356, -0.46518831,  0.51853843,  0.52350237,  0.49333558,
#         0.10842558])), ('force_torque', array([-5.15369435, -5.0502561 , -4.72552216, -5.92721079, -5.71163246,
#        -6.01317097,  5.95161383,  5.87484038, -6.38421312,  4.60480824,
#        -3.75872578, -2.82845212, -2.47313966,  2.38802322, -0.4348187 ,
#        -3.13000289,  3.38934825, -0.58423546,  3.33567858, -3.30800316,
#        -1.03994631, -0.01015536, -0.45312967, -0.15418427])), ('ball_state', array([ 9.12611012, -7.89217042, -0.02524848, -1.12734486, -1.66222613,
#        -0.08587451,  6.43108932, 10.63001772,  5.79621839]))]))
# TimeStep(step_type=<StepType.MID: 1>, reward=600, discount=1.0, observation=OrderedDict([('egocentric_state', array([ 0.56444629,  0.78322727, -0.58764091, -0.20240329,  0.50057191,
#         0.79969875, -0.6548933 , -0.14275354,  0.57344761,  0.73939969,
#        -0.62489176, -0.11477667,  0.43563289,  0.70968232, -0.6608945 ,
#        -0.04619984, -0.70995383, -0.78336316,  1.78813769, -0.25503628,
#        -0.1248818 , -0.52649581, -0.03138931,  0.72811756,  0.72387768,
#        -0.93391615,  0.32378625,  0.35076999, -0.48671997,  0.14343571,
#        -0.07489294,  0.5995298 ,  0.55927507,  0.62618877,  0.32238962,
#         0.56118157,  0.49850508,  0.52576716,  0.59404116,  0.47852038,
#         0.4851634 ,  0.44386563,  0.34224353,  0.48426668])), ('torso_velocity', array([-0.10352419, -0.04773578, -0.16881191])), ('torso_upright', array(0.99968822)), ('imu', array([ 1.51852825,  4.3296729 ,  4.48631483,  0.55613794,  0.16556966,
#        -0.11998862])), ('force_torque', array([-6.26245107, -4.1451093 , -5.26966428,  4.31670206,  4.08787645,
#        -3.98201374,  5.34410292,  4.19589525, -6.29099213, -3.11926683,
#         3.41011151,  0.45212192, -1.79661467,  3.46446653,  0.53060478,
#         0.06576042, -0.50383891,  0.08682306,  1.75569089, -2.60286344,
#         0.10812515, -0.06835745, -0.2002087 ,  0.23030767])), ('ball_state', array([ 8.13922122, -9.6925328 , -0.60310444, -0.77288667, -0.16207526,
#        -0.33091934,  3.06332179,  8.68166081,  3.4873959 ]))]))
# ===========
# timestep: 500
# ball in goal: False
# ball_to_goal_distance: 15.235938577791842
# ===========
#
# ===========
# timestep: 500
# ball in goal: False
# ball_to_goal_distance: 15.235938577791842
# ===========
#
# TimeStep(step_type=<StepType.MID: 1>, reward=600, discount=1.0, observation=OrderedDict([('egocentric_state', array([ 0.35298027,  0.77051471, -0.65481368, -0.11676484,  0.38279618,
#         0.74999695, -0.6995324 , -0.04644029,  0.53703958,  0.8060236 ,
#        -0.73909831, -0.06231506,  0.55105479,  0.82039005, -0.75333338,
#        -0.06459658,  1.01511369, -0.66025143,  0.72214099,  0.40391935,
#        -0.93194995, -1.17097278,  0.29050384,  1.60425884,  1.0870082 ,
#         0.3301874 , -0.4499456 , -0.07393413,  1.52802975, -0.39301155,
#         1.0317429 , -1.37740675,  0.46242315,  0.61225034,  0.43946461,
#         0.33547834,  0.3007537 ,  0.48560876,  0.53768596,  0.69261502,
#         0.59466582,  0.64574849,  0.54888369,  0.49092639])), ('torso_velocity', array([-0.00749279,  0.15618935, -0.09103488])), ('torso_upright', array(0.99999149)), ('imu', array([ 8.25772013e+00,  3.05161831e+00,  9.48147109e+00, -6.44575182e-02,
#        -8.90927402e-04, -7.14424301e-01])), ('force_torque', array([-4.98048487,  5.57265951, -6.55948646,  2.75838687,  3.37238221,
#        -2.48462082,  5.5911523 ,  4.32168034, -7.0158908 ,  6.30529963,
))]))
# TimeStep(step_type=<StepType.MID: 1>, reward=600, discount=1.0, observation=OrderedDict([('egocentric_state', array([ 0.59477899,  0.64637739, -0.41871511, -0.22299614,  0.51683003,
#         0.80172899, -0.6336396 , -0.16604017,  0.54671933,  0.75963355,
#        -0.60632491, -0.15275441,  0.54039591,  0.63079168, -0.45511235,
#        -0.17742864,  0.16877159,  0.97149183, -0.05698915, -0.72796869,
#        -0.96909906,  0.30727889, -0.29565242,  0.41030083, -0.65343362,
#        -1.26553567,  0.38245386,  0.79909718,  0.63789904, -0.07303512,
#        -0.85444768,  1.13095745,  0.49487843,  0.58548592,  0.42554637,
#         0.57096838,  0.57851193,  0.54606473,  0.45498903,  0.37729469,
#         0.4490334 ,  0.62093127,  0.45950198,  0.38858586])), ('torso_velocity', array([-0.06428318, -0.072197  , -0.04572652])), ('torso_upright', array(0.9993941)), ('imu', array([-3.67883513, -3.06845524, 14.12782139,  0.54290736, -0.43924122,
#         0.10568037])), ('force_torque', array([ 6.81517642, -5.7702252 , -7.03257659,  6.05551078,  5.68222681,
#        -6.64717517,  5.52865173, -5.53318861, -5.71483077, -3.26329235,
#         5.15194265, -6.12060824, -3.31293923, -4.22367675, -1.07848946,
#         3.07553783, -3.57033341, -0.59804128, -2.9588487 , -2.98206395,
#         0.51525239,  2.65577048,  0.32288901,  0.19114268])), ('ball_state', array([ 3.28054765, -7.36717675, -0.89566148, -0.13313983,  0.24250173,
#         0.03437357,  1.68107842, -0.20488184,  0.3675328 ]))]))
# TimeStep(step_type=<StepType.LAST: 2>, reward=600, discount=1.0, observation=OrderedDict([('egocentric_state', array([ 5.62186275e-01,  6.44318677e-01, -6.49989629e-01,  4.17789572e-03,
#         5.22058070e-01,  6.01884713e-01, -5.33056915e-01, -6.91309466e-02,
#         5.18016159e-01,  6.68428241e-01, -4.64935337e-01, -2.10903991e-01,
#         3.90292414e-01,  6.45714535e-01, -4.45828342e-01, -1.96920109e-01,
#         4.90357434e-01,  9.73912208e-01, -1.35692376e+00,  1.82987603e-01,
#         6.62922339e-01, -3.47107414e-01, -2.48988159e-05,  3.54664195e-01,
#         8.99220670e-01,  3.94758170e-01, -1.37680476e+00,  1.45136165e+00,
#         6.17391304e-01,  1.16115690e+00, -4.69817242e-01, -1.21785268e+00,
#         5.79868547e-01,  6.26678987e-01,  5.84721725e-01,  5.67652331e-01,
#         4.23857763e-01,  4.25406346e-01,  5.91014421e-01,  5.59792974e-01,
#         4.07758842e-01,  4.12463786e-01,  5.70066311e-01,  4.05978930e-01])), ('torso_velocity', array([ 0.15056853, -0.21012025,  0.10641506])), ('torso_upright', array(0.9989707)), ('imu', array([-1.41318568, -3.74445175, 15.4136629 ,  0.26456682,  0.28221032,
#        -0.42501485])), ('force_torque', array([ 5.39314523, -4.35161747, -7.03841285,  5.15136133,  5.27848187,
#        -6.49838564, -6.40937054,  4.95301664, -5.76644476,  5.64147583,
#         2.94362398, -6.37470634, -1.42632232, -2.69772207,  0.28284434,
#         2.66180613, -2.44163196,  0.00972486,  2.21555129,  3.68799474,
#         0.46649564,  1.3915419 , -2.78457162,  0.32287767])), ('ball_state', array([ 2.45200566, -7.25410623, -0.64080252, -0.26215649,  0.32166635,
#        -0.11640833,  0.99291603, -0.19861092,  0.28404202]))]))
